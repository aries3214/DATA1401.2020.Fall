# %% [markdown]
# # Lab 3- Tic Tac Toe
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/UTA-DataScience/DATA1401.2020.Fall/blob/master/Labs/Lab.3/Lab.3.ipynb)
#
# In this lab your will build a n x n Tic Tac Toe game. As you do the exercises, make sure your solutions work for any size Tic Tac Toe game.

# %% [markdown]
# *Exercise 1:* Write a function that creates an n by n matrix (of list of lists) which will represent the state of a Tie Tac Toe game. Let 0, 1, and 2 represent empty, "X", or "O".

# %%
# Write you solution here
p1=1
p2=2
empty=0
size=3
def draw_matrix(size):
  mtrx=[([empty])*size for i in range(size)]
  return mtrx

# %%
# Test your solution here
board=draw_matrix(3)
board
# Out:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# *Exercise 2:* Write a function that takes a `n` by `n` matrix representing a tic-tac-toe game, and returns -1, 0, 1, or 2 indicating the game is incomplete, the game is a draw, player 1 has won, or player 2 has one, respectively. Here are some example inputs you can use to test your code:

# %%
winner_is_2 = [[2, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_1 = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_also_1 = [[0, 1, 0],
	[2, 1, 0],
	[2, 1, 1]]

no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 2]]

also_no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 0]]

# %%
# Write you solution here
def check_game(matrx):
  size=len(matrx)
  for i in range(size):
    row=set([matrx[i][0],matrx[i][1],matrx[i][2]])
    col=set([matrx[0][i],matrx[1][i],matrx[2][i]])
    if len(row)==1 and matrx[i][0]!=0:
      if matrx[i][0]==1:
        return"Player 1 wins"
      elif matrx[i][0]==2:
        return"Player 2 wins"
    elif len(col)==1 and matrx[0][i]!=0:
      if matrx[0][i]==1:
        return"Player 1 wins"
      elif matrx[0][i]==2:
        return"Player 2 wins"
    else:
        return"No winner"
    
    diag1=set(matrx[i][i] for i in range(size))
    diag2=set(matrx[i][size-i-1] for i in range(size))
    if len(diag1) or len(diag2)==1 and matrx[1][1]!=0:
      if matrx[1][1]==1:
        return"Player 1 wins"
      elif matrx[1][1]==2:
        return"Player 2 wins"
    else:
        return"No winner"

# %%
# Test your solution here
mat=winner_is_1
check_game(mat)
# Out:
# 'No winner'

# %% [markdown]
# *Exercise 3:* Write a function that takes 2 integers `n` and `m` as input and draws a `n` by `m` game board. For example the following is a 3x3 board:
# ```
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#    ```

# %%
# Write you solution here
def draw_game(bd_size):
  for i in range(bd_size):
    print(" ---" * bd_size)
    print("|   " * (bd_size+1))
  return print(" ---" * bd_size)

# %%
# Test your solution here
draw_game(3)
# Out:
#  --- --- ---
# |   |   |   |
#  --- --- ---
# |   |   |   |
#  --- --- ---
# |   |   |   |
#  --- --- ---

# %% [markdown]
# *Exercise 4:* Modify exercise 3, so that it takes a matrix of the form from exercise 2 and draws a tic-tac-tie board with "X"s and "O"s.

# %%
# Write you solution here
p1p='X'
p2p='O'
ep=' '
def char_space(player):
  if player==p1:
    return p1p
  elif player==p2:
    return p2p
  else:
    return ep

char_space={p1: p1p,
            p2: p2p,
            empty: ep}

def draw_board(matrix):
  for i in range(size):
    print(" --- "*size)
    for j in range(size):
      print("| ",end=char_space[matrix[i][j]]+' |')
    print()

# %%
# Test your solution here
board0=draw_board(board)
# Out:
#  ---  ---  ---
# |   ||   ||   |
#  ---  ---  ---
# |   ||   ||   |
#  ---  ---  ---
# |   ||   ||   |

# %% [markdown]
# *Exercise 5:* Write a function that takes a game board, player number, and `(x,y)` coordinates and places "X" or "O" in the correct location of the game board. Make sure that you only allow filling previously empty locations. Return `True` or `False` to indicate successful placement of "X" or "O".

# %%
# Write you solution here
def message(message, verbose=True):
  if verbose:
    print(message)
def play_move(matrix, player,location,verbose=True):
  x,y=location
  if not matrix[x][y]==player:
    message("Spot available",verbose)
    return False
  if matrix[x][y]!=player and matrix[x][y]==empty:
    matrix[x][y]=player
    return True

# %%
# Test your solution here
board=play_move(board,p1,(0,1))
board
# Out:
# Spot available
# False

# %% [markdown]
# *Exercise 6:* Modify Exercise 4 to show column and row labels so that players can specify location using "A2" or "C1".

# %%
# Write you solution here
h=list("ABCDEFGHIJKLM")
h_map=dict(zip(h,range(size)))
v=list(map(str,range(1,size+1)))
v_map=dict(zip(v,range(size)))
v_map
# Out:
# {'1': 0, '2': 1, '3': 2}

# %%
def draw_board(matrix):
  for j in range(size):
    print(h[j],end=" ")
  print()
  for i in range(size):
    print(v[i],end=" ")
    print(" --- "*size)
    for j in range(size):
      print(" | ",end=char_space[matrix[i][j]]+' ')
    print()

# %%
# Test your solution here
draw_board(mat)
# Out:
# A B C
# 1  ---  ---  ---
#  | X  | O  |
# 2  ---  ---  ---
#  | O  | X  |
# 3  ---  ---  ---
#  | O  | X  | X

# %% [markdown]
# *Exercise 7:* Write a function that takes a board, player number, and location specified as in exercise 6 and then calls exercise 5 to correctly modify the board.

# %%
# Write you solution here

# %%
# Test your solution here

# %% [markdown]
# *Exercise 8:* Write a function is called with a board and player number, takes input from the player using python's `input`, and modifies the board using your function from exercise 7. Note that you should keep asking for input until you have gotten a valid input that results in a valid move.

# %%
# Write you solution here

# %%
# Test your solution here

# %% [markdown]
# *Exercise 9:* Use all of the previous exercises to implement a full tic-tac-toe game, where an appropriate board is drawn, 2 players are repeatedly asked for a location coordinates of where they wish to place a mark, and the game status is checked until a player wins or a draw occurs.

# %%
# Write you solution here

# %%
# Test your solution here

# %% [markdown]
# *Exercise 10:* Test that your game works for 5x5 Tic Tac Toe.

# %%
# Test your solution here

# %% [markdown]
# *Exercise 11: (Extra Credit)* Develop a version of the game where one player is the computer. Note that you don't need to do an extensive seach for the best move. You can have the computer simply protect against loosing and otherwise try to win with straight or diagonal patterns.

# %%
# Write you solution here

# %%
# Test your solution here
